# %% [markdown]
# <a href="https://colab.research.google.com/github/tafakuri/elewa/blob/main/Dataset_Validator_for_Wav2Vec_BBC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install required packages

# %%
# !pip install datasets 
# !pip install transformers
# !pip install torch
# !pip install torchaudio
# !pip install accelerate>=0.5.0
# !pip install librosa
# !pip install tensorboard
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 432 kB 31.6 MB/s
# ...
#      |████████████████████████████████| 212 kB 87.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 89.2 MB/s
# ...
#      |████████████████████████████████| 115 kB 94.2 MB/s
# ...
#      |████████████████████████████████| 127 kB 79.8 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 31.7 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 75.4 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Log in to HuggingFace hub

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
from datasets import load_dataset, load_metric, Audio

unlabled_dataset_train = load_dataset("mutisya/bbc_v0", split="train", use_auth_token=True)
# Out:
# WARNING:datasets.builder:Using custom data configuration mutisya--bbc_v0-e5be95472ee0115e
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/mutisya___parquet/mutisya--bbc_v0-e5be95472ee0115e/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
unlabled_dataset_train[0]
# Out:
# {'audio': {'path': None,
#   'array': array([ 0.00262451,  0.00152588, -0.00076294, ...,  0.00143433,
#           0.00085449,  0.00091553]),
#   'sampling_rate': 16000}}

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(unlabled_dataset_train)-1)

ipd.Audio(data=np.asarray(unlabled_dataset_train[rand_int]["audio"]["array"]), autoplay=True, rate=16000)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
